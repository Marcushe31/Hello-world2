# %% [markdown]
# <h1>Individual Project: Marcus Hernandez

# %% [markdown]
# My name is Marcus Hernandez, and this is my end of the trimester individual Project review ! I've learned much throughout this trimester, and I have gained much experience in the computer science course. Here is the summary of my reflection that I will be going over through this review:

# %% [markdown]
# <li> Weekly Reflections (review tickets)
# <li> Weekly Plans
# <li> Team Teach Reflections
# <li> Code reflections topic learned:
# <li> Our group's use of Agile Methodology
# <li> My Passion Project Code
# <li> Issues on Github for Passion project
# <li> Other code and mini-projects
# <li> Study For AP Exam

# %% [markdown]
# <h1>1. Weekly Reflections

# %% [markdown]
# <h5> Week 1 Review Ticket </h5>
# This week I learned much about Vscode, Github, and how everything is going to work. I was able to setup all of the requirements for vscode, aswell as github. I learned that we will be creating a webpage, which we can add different things like games, a notebook of our work, and other things. I was able to do my first live review, which I showed that my webpage was able to work properly, and that I had added all of the requirements of the week.
#
# <h5> Week 12 Review Ticket </h5>
#
# This week we made some final touches to our backend and frontend for the passion project, we were able to be qualified for night of the museum on wednesday, and then present our project at the night of the museum on Thursday. I belive it went well, many people were able to see our project and we were able to explain how everything worked to everyone. Overall this week went great, I am looking forward to next week with finals.

# %% [markdown]
# # 2. Weekly Plans

# %% [markdown]
# <h5>Week 1 Plan </h5>
#
# This is the first week of AP Computer Science Principles, I am eager learn much in this trimester and to carry on to the next trimester. This week, I plan to setup my github account, aswell as install vscode. I also will work on linking my VSCode account to my vscode, and connecting/clonin the repository. Finally, I want to download all of the stuff that we need
#
# <h5>Week 12 Plan </h5>
#
# This is the second to last week before we are finished with the first trimester, the focus for this week is about the Night At the Museum. This week, I plan to first qualify for Night At the Museum on wednesday,and then present my group's passion project about the Del Norte Football Cards on Thursday. I want to make some finishing touches to the backend and MaxPreps API, aswell as some nice visual touches to the front end.

# %% [markdown]
# # 3. Team Tech Talk Reflections

# %% [markdown]
# Overall, all of the Team Tech Talks were very helpful and gave me different tools to use utilize in my Passion Project. Overall, we learned about:

# %% [markdown]
# <li>Data Abstraction
# <li>Algorithms
# <li>Boolean
# <li>Iterations (my team's Tech Talk)
# <li>Developing Algorithms
# <li>Lists and Search
# <li>Developing Procedures
# <li> Libraries
# <li> Simulations

# %% [markdown]
# While there is much knowledge, I won't go over all of it. I will show some of the many screenshots of my individual notes and popcorn hacks aswell as homeworks from the Team Tech Talks. As an example, I will go over 1 of my summaries of team tech talks.

# %% [markdown]
# Boolean:
# In computer science, a boolean is a data type that represents one of two possible values: true or false. Booleans are fundamental for making decisions in programming, as they are used in conditional statements and control flow to determine whether certain conditions are met.

# %%
is_true = True

if is_true:
    print("The boolean is true.")
else:
    print("The boolean is false.")

# %% [markdown]
# # 4. Code Reflections Topics Learned

# %% [markdown]
# Over this short trimester I've learned much about computer science. Here is the summary of some of the code types that I've learned about, such as HTML, CSS, JavaScript.

# %% [markdown]
# <h3>HTML:</h3>
#  <li>HTML is a markup language used to structure the content and define the elements on a web page.
# <li>It provides the basic building blocks for web content, such as headings, paragraphs, links, images, forms, and more.
# <li>HTML defines the structure of a web page and its content but does not handle styling or interactivity.

# %% [markdown]
# <h3>CSS (Cascading Style Sheets)</h3>
# <li>CSS is a stylesheet language used for styling and layout of web pages.
# <li>It allows you to control the visual presentation of HTML elements, specifying aspects like colors, fonts, margins, padding, and positioning.
# <li>CSS separates the content (HTML) from its presentation, enabling consistent and customizable designs across websites.

# %% [markdown]
# <h3>JavaScript</h3>
# <li> JavaScript is a programming language used for adding interactivity and behavior to web pages.
# <li>It enables dynamic features like user interactions, animations, form validation, and data manipulation.
# <li>JavaScript can be used to respond to events, modify the content of a web page, and communicate with servers

# %% [markdown]
# # 5. Our Group's Use of Agile Methodology

# %% [markdown]
# <h4>Our group for the passion project and shared repository consisted of me (Marcus), Kayden L, Hao Y, and Ameer H. Out of everyone, I was the scrum master, meaning that I tried to make sure that we had completed work on time, and that everyone was participating and completing their share of code. I feel like at times our group struggled for all members to participate and sometimes I found only myself working on a project (at times), but we were able to complete all assignments (mostly) on time. </h4>

# %% [markdown]
# # 6. My Passion Project Code

# %% [markdown]
# Backend Code:
# ![projectye.PNG](attachment:projectye.PNG)

# %% [markdown]
# <h3> Frontend Code:
#
# <html>
# <head>
#     <title>Player Info</title>
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#         }
#         .header {
#             background-color: #333;
#             color: white;
#             padding: 10px 0;
#             text-align: center;
#         }
#         .profile {
#             width: 80%;
#             margin: 20px auto;
#             border: 1px solid #ddd;
#             padding: 20px;
#         }
#         .profile img {
#             width: 200px;
#             height: 200px;
#             border: 2px solid black;
#             display: block;
#             margin: 0 auto;
#         }
#         .profile h1 {
#             font-weight: bold;
#             text-align: center;
#         }
#         .bio {
#             margin-top: 20px;
#         }
#         .bio p {
#             font-size: 18px;
#         }
#     </style>
# </head>
# <body>
#     <div class="header">
#         <h1>Sean Lobanov</h1>
#     </div>
#     <div class="profile">
#         <img src="https://static.hudl.com/users/prod/14771640_ab1b66ec16fc436687ebd73eb2e87d0f.jpg" alt="Sean Lobanov">
#         <h1>Sean Lobanov #70</h1>
#         <div class="bio">
#           <a href="https://www.maxpreps.com/ca/san-diego/del-norte-nighthawks/athletes/sean-lobanov/football/stats/?careerid=ip0vvee272psc">View on MaxPreps Here:</a>
#             <p><strong>Plays:</strong> Football</p>
#             <p><strong>Class Year:</strong> Senior - 2024</p>
#             <p><strong>Teams:</strong> Del Norte Varsity Football</p>
#             <p><strong>Position:</strong> Offensive Lineman</p>
#             <p><strong>Measurements:</strong></p>
#             <p>Height: 5'7"</p>
#             <p>Weight: 320 lbs</p>
#             <p><strong>Stats:</strong></p>
#             <li> 10 Pancakes </li>
#             <li> 200lbs Bench Press </li>
#             <li> 301lbs Squat</li>
#         </div>
#     </div>
# </body>
# </html>

# %% [markdown]
# # 7. Issues On Github: Reviews from Other people

# %% [markdown]
# From Miguel:

# %% [markdown]
# ![miguelreview.PNG](attachment:miguelreview.PNG)

# %% [markdown]
# From Jayden:

# %% [markdown]
# ![jaydenreview.PNG](attachment:jaydenreview.PNG)

# %% [markdown]
# From Beijan

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# These were the three that reviewed our Passion Project, the total for all of the points add up to... (I made an arithmetic calculation code for this)

# %%
score1 = 8.35
score2 = 8.43
score3 = 8.6

total_score = score1 + score2 + score3
median_average = total_score / 27

print("Median Average Score:", median_average)
# Out:
# Median Average Score: 0.9400000000000001

# %% [markdown]
# # 8. Other Code and Mini Projects

# %% [markdown]
# Below is some of the mini projects and code that I created (or found)throughout the trimester.

# %% [markdown]
# <html>
# <head>
#     <title>Quiz</title>
# </head>
# <body>
#     <h1>Quiz</h1>
#     <form id="quiz-form">
#         <ol>
#             <li>
#                 <h3>What is the capital of the United States?</h3>
#                 <input type="radio" name="q1" value="a"> a) Madrid<br>
#                 <input type="radio" name="q1" value="b"> b) Paris<br>
#                 <input type="radio" name="q1" value="c"> c) Washington DC<br>
#             </li>
#             <li>
#                 <h3>What is the biggest company in the world?</h3>
#                 <input type="radio" name="q2" value="a"> a) Apple<br>
#                 <input type="radio" name="q2" value="b"> b) Google<br>
#                 <input type="radio" name="q2" value="c"> c) Amazon<br>
#             </li>
#             <li>
#                 <h3>How many continents are there on Earth?</h3>
#                 <input type="radio" name="q3" value="a"> a) 4<br>
#                 <input type="radio" name="q3" value="b"> b) 6<br>
#                 <input type="radio" name="q3" value="c"> c) 7<br>
#             </li>
#             <li>
#                 <h3>Which gas do plants absorb from the atmosphere?</h3>
#                 <input type="radio" name="q4" value="a"> a) Oxygen<br>
#                 <input type="radio" name="q4" value="b"> b) Carbon Dioxide<br>
#                 <input type="radio" name="q4" value="c"> c) Nitrogen<br>
#             </li>
#             <li>
#                 <h3>What is the largest mammal in the world?</h3>
#                 <input type="radio" name="q5" value="a"> a) Elephant<br>
#                 <input type="radio" name="q5" value="b"> b) Giraffe<br>
#                 <input type="radio" name="q5" value="c"> c) Blue Whale<br>
#             </li>
#         </ol>
#         <input type="submit" value="Submit">
#     </form>
#     <script>
#         document.getElementById('quiz-form').addEventListener('submit', function (e) {
#             e.preventDefault(); // Prevent the form from submitting
#             // Define the correct answers
#             const correctAnswers = ['c', 'a', 'b', 'b', 'c'];
#             // Get the user's answers
#             const userAnswers = [
#                 document.querySelector('input[name="q1"]:checked').value,
#                 document.querySelector('input[name="q2"]:checked').value,
#                 document.querySelector('input[name="q3"]:checked').value,
#                 document.querySelector('input[name="q4"]:checked').value,
#                 document.querySelector('input[name="q5"]:checked').value,
#             ];
#             // Check the answers and display the result
#             let score = 0;
#             for (let i = 0; i < correctAnswers.length; i++) {
#                 if (userAnswers[i] === correctAnswers[i]) {
#                     score++;
#                 }
#             }
#             const resultMessage = `You got ${score} out of ${correctAnswers.length} questions correct.`;
#             alert(resultMessage);
#         });
#     </script>
# </body>
# </html>

# %% [markdown]
# <html>
# <head>
#     <title>Hangman Game</title>
#     <style>
#     </style>
# </head>
# <body>
#     <h1>Hangman Game</h1>
#     <p>Guess the word:</p>
#     <div id="word-container"></div>
#     <p>Incorrect Guesses: <span id="incorrect-guesses">0</span></p>
#     <p>Incorrect Letters: <span id="incorrect-letters"></span></p>
#     <input type="text" id="guess-input" maxlength="1">
#     <button onclick="makeGuess()">Guess</button>
#     <button onclick="newGame()">New Game</button>
#     <script>
#         const words = ["apple", "banana", "cherry", "orange", "grape", "kiwi", "lemon", "monkey", "bird", "happy", " Pneumonoultramicroscopicsilicovolcanoconiosis", "mango"];
#         let word;
#         let guessedWord;
#         let incorrectGuesses = 0;
#         let incorrectLetters = [];
#         const maxIncorrectGuesses = 6;
#         function newGame() {
#             word = words[Math.floor(Math.random() * words.length)];
#             guessedWord = "_".repeat(word.length);
#             incorrectGuesses = 0;
#             incorrectLetters = [];
#             updateDisplay();
#         }
#         function updateDisplay() {
#             document.getElementById("word-container").textContent = guessedWord;
#             document.getElementById("incorrect-guesses").textContent = incorrectGuesses;
#             document.getElementById("incorrect-letters").textContent = incorrectLetters.join(", ");
#         }
#         function makeGuess() {
#             const guess = document.getElementById("guess-input").value.toLowerCase();
#             if (guess.length !== 1 || !guess.match(/[a

# %% [markdown]
# # Code:

# %% [markdown]
# Object(Python):

# %%
class Person:
    def __init__(self, name):
        self.name = name


marcus = Person("Marcus")


print("Object's name:", marcus.name)
# Out:
# Object's name: Marcus

# %% [markdown]
# Table(HTML):

# %% [markdown]
# <table>
# <tr>
# <th>Class</th>
# <th>Period</th>
# </tr>
# <tr>
# <td> Ethnic Literature</td>
# <td>Period 1</td>
# </tr>
# <tr>
# <td>Physics</td>
# <td>Period 2</td>
# </tr>
# <tr>
# <td>Ap Calculus</td>
# <td>Period 3</td>
# </tr>
# <tr>
# <td>Ap Computer Science Principles</td>
# <td>Period 4</td>
# </tr>
# <tr>
# <td>Advanced Football PE</td>
# <td>Period 5</td>
# </tr>
# </table>

# %% [markdown]
# Variable(Python):

# %%
def greet(name):
    message = "Hello, " + name + "!"
    return message

result = greet("Marcus")
print(result)

# %% [markdown]
# Explanation: As you can see from the code, we defined the variable of greet, which represents the mess = hello + name + !. The return statement is returning the message variable. After that, we defined the variable of result as the greet function, plus the name ("Marcus") which will go into the message function. Finally, we will print the (result) and it will give us our code = Hello, Marcus!

# %% [markdown]
# ![Flowchart](https://www.conceptdraw.com/How-To-Guide/picture/Flowchart-Example2.png)

# %% [markdown]
# # 9. Study For AP Exam

# %% [markdown]
# <h3>As for studying for the AP EXAM, I am registered for: May 15, 12:00 PM, in terms of studying for the AP EXAM, I plan to complete all of the assignments and watch all of the videos on College Board, aswell as take the many practice AP EXAM MC quizzes so that I can be on track with the course that is on college board.

# %% [markdown]
# # Memories of Trimester 1:

# %% [markdown]
# I think my favorite project from Trimester one was the passion project, as I was able to create something that I was very "passionate" about. While we had many struggles throughout the trimester, I am excited for the next trimester that is to come.

# %% [markdown]
# # This is my reflection, thank you for your time !
